# %% [markdown]
# FGV - Escola de Matemática Aplicada
# ==
# Introdução à Programação com a Linguagem Python
# --

# %% [markdown]
# #### Resolvendo o problema 4 do Project Euler:
# https://projecteuler.net/problem=4
#
# "A palindromic number reads the same both ways. The largest palindrome made from the product of two 2-digit numbers is 9009 = 91 × 99.
# Find the largest palindrome made from the product of two 3-digit numbers."

# %% [markdown]
# ###### Como inverter uma string?
# Antes vamos entender como inverter uma string

# %%
'Uma string comum'[0:7]
# Out:
# 'Uma str'

# %%
list(range(999,99,-1))
# Out:
# [999,
#  998,
#  997,
#  996,
#  995,
#  994,
#  993,
#  992,
#  991,
#  990,
#  989,
#  988,
#  987,
#  986,
#  985,
#  984,
#  983,
#  982,
#  981,
#  980,
#  979,
#  978,
#  977,
#  976,
#  975,
#  974,
#  973,
#  972,
#  971,
#  970,
#  969,
#  968,
#  967,
#  966,
#  965,
#  964,
#  963,
#  962,
#  961,
#  960,
#  959,
#  958,
#  957,
#  956,
#  955,
#  954,
#  953,
#  952,
#  951,
#  950,
#  949,
#  948,
#  947,
#  946,
#  945,
#  944,
#  943,
#  942,
#  941,
#  940,
#  939,
#  938,
#  937,
#  936,
#  935,
#  934,
#  933,
#  932,
#  931,
#  930,
#  929,
#  928,
#  927,
#  926,
#  925,
#  924,
#  923,
#  922,
#  921,
#  920,
#  919,
#  918,
#  917,
#  916,
#  915,
#  914,
#  913,
#  912,
#  911,
#  910,
#  909,
#  908,
#  907,
#  906,
#  905,
#  904,
#  903,
#  902,
#  901,
#  900,
#  899,
#  898,
#  897,
#  896,
#  895,
#  894,
#  893,
#  892,
#  891,
#  890,
#  889,
#  888,
#  887,
#  886,
#  885,
#  884,
#  883,
#  882,
#  881,
#  880,
#  879,
#  878,
#  877,
#  876,
#  875,
#  874,
#  873,
#  872,
#  871,
#  870,
#  869,
#  868,
#  867,
#  866,
#  865,
#  864,
#  863,
#  862,
#  861,
#  860,
#  859,
#  858,
#  857,
#  856,
#  855,
#  854,
#  853,
#  852,
#  851,
#  850,
#  849,
#  848,
#  847,
#  846,
#  845,
#  844,
#  843,
#  842,
#  841,
#  840,
#  839,
#  838,
#  837,
#  836,
#  835,
#  834,
#  833,
#  832,
#  831,
#  830,
#  829,
#  828,
#  827,
#  826,
#  825,
#  824,
#  823,
#  822,
#  821,
#  820,
#  819,
#  818,
#  817,
#  816,
#  815,
#  814,
#  813,
#  812,
#  811,
#  810,
#  809,
#  808,
#  807,
#  806,
#  805,
#  804,
#  803,
#  802,
#  801,
#  800,
#  799,
#  798,
#  797,
#  796,
#  795,
#  794,
#  793,
#  792,
#  791,
#  790,
#  789,
#  788,
#  787,
#  786,
#  785,
#  784,
#  783,
#  782,
#  781,
#  780,
#  779,
#  778,
#  777,
#  776,
#  775,
#  774,
#  773,
#  772,
#  771,
#  770,
#  769,
#  768,
#  767,
#  766,
#  765,
#  764,
#  763,
#  762,
#  761,
#  760,
#  759,
#  758,
#  757,
#  756,
#  755,
#  754,
#  753,
#  752,
#  751,
#  750,
#  749,
#  748,
#  747,
#  746,
#  745,
#  744,
#  743,
#  742,
#  741,
#  740,
#  739,
#  738,
#  737,
#  736,
#  735,
#  734,
#  733,
#  732,
#  731,
#  730,
#  729,
#  728,
#  727,
#  726,
#  725,
#  724,
#  723,
#  722,
#  721,
#  720,
#  719,
#  718,
#  717,
#  716,
#  715,
#  714,
#  713,
#  712,
#  711,
#  710,
#  709,
#  708,
#  707,
#  706,
#  705,
#  704,
#  703,
#  702,
#  701,
#  700,
#  699,
#  698,
#  697,
#  696,
#  695,
#  694,
#  693,
#  692,
#  691,
#  690,
#  689,
#  688,
#  687,
#  686,
#  685,
#  684,
#  683,
#  682,
#  681,
#  680,
#  679,
#  678,
#  677,
#  676,
#  675,
#  674,
#  673,
#  672,
#  671,
#  670,
#  669,
#  668,
#  667,
#  666,
#  665,
#  664,
#  663,
#  662,
#  661,
#  660,
#  659,
#  658,
#  657,
#  656,
#  655,
#  654,
#  653,
#  652,
#  651,
#  650,
#  649,
#  648,
#  647,
#  646,
#  645,
#  644,
#  643,
#  642,
#  641,
#  640,
#  639,
#  638,
#  637,
#  636,
#  635,
#  634,
#  633,
#  632,
#  631,
#  630,
#  629,
#  628,
#  627,
#  626,
#  625,
#  624,
#  623,
#  622,
#  621,
#  620,
#  619,
#  618,
#  617,
#  616,
#  615,
#  614,
#  613,
#  612,
#  611,
#  610,
#  609,
#  608,
#  607,
#  606,
#  605,
#  604,
#  603,
#  602,
#  601,
#  600,
#  599,
#  598,
#  597,
#  596,
#  595,
#  594,
#  593,
#  592,
#  591,
#  590,
#  589,
#  588,
#  587,
#  586,
#  585,
#  584,
#  583,
#  582,
#  581,
#  580,
#  579,
#  578,
#  577,
#  576,
#  575,
#  574,
#  573,
#  572,
#  571,
#  570,
#  569,
#  568,
#  567,
#  566,
#  565,
#  564,
#  563,
#  562,
#  561,
#  560,
#  559,
#  558,
#  557,
#  556,
#  555,
#  554,
#  553,
#  552,
#  551,
#  550,
#  549,
#  548,
#  547,
#  546,
#  545,
#  544,
#  543,
#  542,
#  541,
#  540,
#  539,
#  538,
#  537,
#  536,
#  535,
#  534,
#  533,
#  532,
#  531,
#  530,
#  529,
#  528,
#  527,
#  526,
#  525,
#  524,
#  523,
#  522,
#  521,
#  520,
#  519,
#  518,
#  517,
#  516,
#  515,
#  514,
#  513,
#  512,
#  511,
#  510,
#  509,
#  508,
#  507,
#  506,
#  505,
#  504,
#  503,
#  502,
#  501,
#  500,
#  499,
#  498,
#  497,
#  496,
#  495,
#  494,
#  493,
#  492,
#  491,
#  490,
#  489,
#  488,
#  487,
#  486,
#  485,
#  484,
#  483,
#  482,
#  481,
#  480,
#  479,
#  478,
#  477,
#  476,
#  475,
#  474,
#  473,
#  472,
#  471,
#  470,
#  469,
#  468,
#  467,
#  466,
#  465,
#  464,
#  463,
#  462,
#  461,
#  460,
#  459,
#  458,
#  457,
#  456,
#  455,
#  454,
#  453,
#  452,
#  451,
#  450,
#  449,
#  448,
#  447,
#  446,
#  445,
#  444,
#  443,
#  442,
#  441,
#  440,
#  439,
#  438,
#  437,
#  436,
#  435,
#  434,
#  433,
#  432,
#  431,
#  430,
#  429,
#  428,
#  427,
#  426,
#  425,
#  424,
#  423,
#  422,
#  421,
#  420,
#  419,
#  418,
#  417,
#  416,
#  415,
#  414,
#  413,
#  412,
#  411,
#  410,
#  409,
#  408,
#  407,
#  406,
#  405,
#  404,
#  403,
#  402,
#  401,
#  400,
#  399,
#  398,
#  397,
#  396,
#  395,
#  394,
#  393,
#  392,
#  391,
#  390,
#  389,
#  388,
#  387,
#  386,
#  385,
#  384,
#  383,
#  382,
#  381,
#  380,
#  379,
#  378,
#  377,
#  376,
#  375,
#  374,
#  373,
#  372,
#  371,
#  370,
#  369,
#  368,
#  367,
#  366,
#  365,
#  364,
#  363,
#  362,
#  361,
#  360,
#  359,
#  358,
#  357,
#  356,
#  355,
#  354,
#  353,
#  352,
#  351,
#  350,
#  349,
#  348,
#  347,
#  346,
#  345,
#  344,
#  343,
#  342,
#  341,
#  340,
#  339,
#  338,
#  337,
#  336,
#  335,
#  334,
#  333,
#  332,
#  331,
#  330,
#  329,
#  328,
#  327,
#  326,
#  325,
#  324,
#  323,
#  322,
#  321,
#  320,
#  319,
#  318,
#  317,
#  316,
#  315,
#  314,
#  313,
#  312,
#  311,
#  310,
#  309,
#  308,
#  307,
#  306,
#  305,
#  304,
#  303,
#  302,
#  301,
#  300,
#  299,
#  298,
#  297,
#  296,
#  295,
#  294,
#  293,
#  292,
#  291,
#  290,
#  289,
#  288,
#  287,
#  286,
#  285,
#  284,
#  283,
#  282,
#  281,
#  280,
#  279,
#  278,
#  277,
#  276,
#  275,
#  274,
#  273,
#  272,
#  271,
#  270,
#  269,
#  268,
#  267,
#  266,
#  265,
#  264,
#  263,
#  262,
#  261,
#  260,
#  259,
#  258,
#  257,
#  256,
#  255,
#  254,
#  253,
#  252,
#  251,
#  250,
#  249,
#  248,
#  247,
#  246,
#  245,
#  244,
#  243,
#  242,
#  241,
#  240,
#  239,
#  238,
#  237,
#  236,
#  235,
#  234,
#  233,
#  232,
#  231,
#  230,
#  229,
#  228,
#  227,
#  226,
#  225,
#  224,
#  223,
#  222,
#  221,
#  220,
#  219,
#  218,
#  217,
#  216,
#  215,
#  214,
#  213,
#  212,
#  211,
#  210,
#  209,
#  208,
#  207,
#  206,
#  205,
#  204,
#  203,
#  202,
#  201,
#  200,
#  199,
#  198,
#  197,
#  196,
#  195,
#  194,
#  193,
#  192,
#  191,
#  190,
#  189,
#  188,
#  187,
#  186,
#  185,
#  184,
#  183,
#  182,
#  181,
#  180,
#  179,
#  178,
#  177,
#  176,
#  175,
#  174,
#  173,
#  172,
#  171,
#  170,
#  169,
#  168,
#  167,
#  166,
#  165,
#  164,
#  163,
#  162,
#  161,
#  160,
#  159,
#  158,
#  157,
#  156,
#  155,
#  154,
#  153,
#  152,
#  151,
#  150,
#  149,
#  148,
#  147,
#  146,
#  145,
#  144,
#  143,
#  142,
#  141,
#  140,
#  139,
#  138,
#  137,
#  136,
#  135,
#  134,
#  133,
#  132,
#  131,
#  130,
#  129,
#  128,
#  127,
#  126,
#  125,
#  124,
#  123,
#  122,
#  121,
#  120,
#  119,
#  118,
#  117,
#  116,
#  115,
#  114,
#  113,
#  112,
#  111,
#  110,
#  109,
#  108,
#  107,
#  106,
#  105,
#  104,
#  103,
#  102,
#  101,
#  100]

# %%
'Uma string comum'[-1::-1]
# Out:
# 'mumoc gnirts amU'

# %%
'Uma string comum'[::-1]
# Out:
# 'mumoc gnirts amU'

# %%
for i in range(999,99,-1):
        for j in range(999,99,-1):
            prod = i*j
            num_string = str(prod)
            if num_string == num_string[::-1]:
                print('the largest palindrome made from the product of two 3-digit numbers is {} = {} x {}'.format(prod,i,j))
# Out:
# the largest palindrome made from the product of two 3-digit numbers is 580085 = 995 x 583
# the largest palindrome made from the product of two 3-digit numbers is 514415 = 995 x 517
# the largest palindrome made from the product of two 3-digit numbers is 906609 = 993 x 913
# the largest palindrome made from the product of two 3-digit numbers is 119911 = 991 x 121
# the largest palindrome made from the product of two 3-digit numbers is 282282 = 987 x 286
# the largest palindrome made from the product of two 3-digit numbers is 141141 = 987 x 143
# the largest palindrome made from the product of two 3-digit numbers is 853358 = 982 x 869
# the largest palindrome made from the product of two 3-digit numbers is 650056 = 979 x 664
# the largest palindrome made from the product of two 3-digit numbers is 601106 = 979 x 614
# the largest palindrome made from the product of two 3-digit numbers is 592295 = 979 x 605
# the largest palindrome made from the product of two 3-digit numbers is 543345 = 979 x 555
# the largest palindrome made from the product of two 3-digit numbers is 485584 = 979 x 496
# the largest palindrome made from the product of two 3-digit numbers is 436634 = 979 x 446
# the largest palindrome made from the product of two 3-digit numbers is 378873 = 979 x 387
# the largest palindrome made from the product of two 3-digit numbers is 329923 = 979 x 337
# the largest palindrome made from the product of two 3-digit numbers is 408804 = 978 x 418
# the largest palindrome made from the product of two 3-digit numbers is 204402 = 978 x 209
# the largest palindrome made from the product of two 3-digit numbers is 623326 = 977 x 638
# the largest palindrome made from the product of two 3-digit numbers is 525525 = 975 x 539
# the largest palindrome made from the product of two 3-digit numbers is 299992 = 974 x 308
# the largest palindrome made from the product of two 3-digit numbers is 469964 = 971 x 484
# the largest palindrome made from the product of two 3-digit numbers is 886688 = 968 x 916
# the largest palindrome made from the product of two 3-digit numbers is 804408 = 968 x 831
# the largest palindrome made from the product of two 3-digit numbers is 698896 = 968 x 722
# the largest palindrome made from the product of two 3-digit numbers is 631136 = 968 x 652
# the largest palindrome made from the product of two 3-digit numbers is 616616 = 968 x 637
# the largest palindrome made from the product of two 3-digit numbers is 443344 = 968 x 458
# the largest palindrome made from the product of two 3-digit numbers is 428824 = 968 x 443
# the largest palindrome made from the product of two 3-digit numbers is 270072 = 968 x 279
# the largest palindrome made from the product of two 3-digit numbers is 255552 = 968 x 264
# the largest palindrome made from the product of two 3-digit numbers is 828828 = 966 x 858
# the largest palindrome made from the product of two 3-digit numbers is 414414 = 966 x 429
# the largest palindrome made from the product of two 3-digit numbers is 487784 = 964 x 506
# the largest palindrome made from the product of two 3-digit numbers is 180081 = 963 x 187
# the largest palindrome made from the product of two 3-digit numbers is 888888 = 962 x 924
# the largest palindrome made from the product of two 3-digit numbers is 666666 = 962 x 693
# the largest palindrome made from the product of two 3-digit numbers is 444444 = 962 x 462
# the largest palindrome made from the product of two 3-digit numbers is 222222 = 962 x 231
# the largest palindrome made from the product of two 3-digit numbers is 348843 = 961 x 363
# the largest palindrome made from the product of two 3-digit numbers is 770077 = 959 x 803
# the largest palindrome made from the product of two 3-digit numbers is 653356 = 958 x 682
# the largest palindrome made from the product of two 3-digit numbers is 855558 = 957 x 894
# the largest palindrome made from the product of two 3-digit numbers is 807708 = 957 x 844
# the largest palindrome made from the product of two 3-digit numbers is 696696 = 957 x 728
# the largest palindrome made from the product of two 3-digit numbers is 648846 = 957 x 678
# the largest palindrome made from the product of two 3-digit numbers is 531135 = 957 x 555
# the largest palindrome made from the product of two 3-digit numbers is 489984 = 957 x 512
# the largest palindrome made from the product of two 3-digit numbers is 372273 = 957 x 389
# the largest palindrome made from the product of two 3-digit numbers is 324423 = 957 x 339
# the largest palindrome made from the product of two 3-digit numbers is 165561 = 957 x 173
# the largest palindrome made from the product of two 3-digit numbers is 117711 = 957 x 123
# the largest palindrome made from the product of two 3-digit numbers is 577775 = 955 x 605
# the largest palindrome made from the product of two 3-digit numbers is 723327 = 953 x 759
# the largest palindrome made from the product of two 3-digit numbers is 649946 = 953 x 682
# the largest palindrome made from the product of two 3-digit numbers is 272272 = 952 x 286
# the largest palindrome made from the product of two 3-digit numbers is 219912 = 952 x 231
# the largest palindrome made from the product of two 3-digit numbers is 292292 = 949 x 308
# the largest palindrome made from the product of two 3-digit numbers is 840048 = 946 x 888
# the largest palindrome made from the product of two 3-digit numbers is 821128 = 946 x 868
# the largest palindrome made from the product of two 3-digit numbers is 802208 = 946 x 848
# the largest palindrome made from the product of two 3-digit numbers is 630036 = 946 x 666
# the largest palindrome made from the product of two 3-digit numbers is 611116 = 946 x 646
# the largest palindrome made from the product of two 3-digit numbers is 420024 = 946 x 444
# the largest palindrome made from the product of two 3-digit numbers is 401104 = 946 x 424
# the largest palindrome made from the product of two 3-digit numbers is 210012 = 946 x 222
# the largest palindrome made from the product of two 3-digit numbers is 238832 = 944 x 253
# the largest palindrome made from the product of two 3-digit numbers is 227722 = 941 x 242
# the largest palindrome made from the product of two 3-digit numbers is 595595 = 935 x 637
# the largest palindrome made from the product of two 3-digit numbers is 589985 = 935 x 631
# the largest palindrome made from the product of two 3-digit numbers is 560065 = 935 x 599
# the largest palindrome made from the product of two 3-digit numbers is 554455 = 935 x 593
# the largest palindrome made from the product of two 3-digit numbers is 548845 = 935 x 587
# the largest palindrome made from the product of two 3-digit numbers is 513315 = 935 x 549
# the largest palindrome made from the product of two 3-digit numbers is 507705 = 935 x 543
# the largest palindrome made from the product of two 3-digit numbers is 564465 = 933 x 605
# the largest palindrome made from the product of two 3-digit numbers is 174471 = 933 x 187
# the largest palindrome made from the product of two 3-digit numbers is 861168 = 932 x 924
# the largest palindrome made from the product of two 3-digit numbers is 809908 = 932 x 869
# the largest palindrome made from the product of two 3-digit numbers is 470074 = 929 x 506
# the largest palindrome made from the product of two 3-digit numbers is 489984 = 928 x 528
# the largest palindrome made from the product of two 3-digit numbers is 693396 = 927 x 748
# the largest palindrome made from the product of two 3-digit numbers is 672276 = 926 x 726
# the largest palindrome made from the product of two 3-digit numbers is 579975 = 925 x 627
# the largest palindrome made from the product of two 3-digit numbers is 888888 = 924 x 962
# the largest palindrome made from the product of two 3-digit numbers is 861168 = 924 x 932
# the largest palindrome made from the product of two 3-digit numbers is 828828 = 924 x 897
# the largest palindrome made from the product of two 3-digit numbers is 801108 = 924 x 867
# the largest palindrome made from the product of two 3-digit numbers is 696696 = 924 x 754
# the largest palindrome made from the product of two 3-digit numbers is 636636 = 924 x 689
# the largest palindrome made from the product of two 3-digit numbers is 444444 = 924 x 481
# the largest palindrome made from the product of two 3-digit numbers is 279972 = 924 x 303
# the largest palindrome made from the product of two 3-digit numbers is 252252 = 924 x 273
# the largest palindrome made from the product of two 3-digit numbers is 219912 = 924 x 238
# the largest palindrome made from the product of two 3-digit numbers is 476674 = 922 x 517
# the largest palindrome made from the product of two 3-digit numbers is 780087 = 921 x 847
# the largest palindrome made from the product of two 3-digit numbers is 393393 = 917 x 429
# the largest palindrome made from the product of two 3-digit numbers is 262262 = 917 x 286
# the largest palindrome made from the product of two 3-digit numbers is 131131 = 917 x 143
# the largest palindrome made from the product of two 3-digit numbers is 886688 = 916 x 968
# the largest palindrome made from the product of two 3-digit numbers is 443344 = 916 x 484
# the largest palindrome made from the product of two 3-digit numbers is 513315 = 915 x 561
# the largest palindrome made from the product of two 3-digit numbers is 824428 = 914 x 902
# the largest palindrome made from the product of two 3-digit numbers is 412214 = 914 x 451
# the largest palindrome made from the product of two 3-digit numbers is 906609 = 913 x 993
# the largest palindrome made from the product of two 3-digit numbers is 793397 = 913 x 869
# the largest palindrome made from the product of two 3-digit numbers is 747747 = 913 x 819
# the largest palindrome made from the product of two 3-digit numbers is 650056 = 913 x 712
# the largest palindrome made from the product of two 3-digit numbers is 604406 = 913 x 662
# the largest palindrome made from the product of two 3-digit numbers is 588885 = 913 x 645
# the largest palindrome made from the product of two 3-digit numbers is 491194 = 913 x 538
# the largest palindrome made from the product of two 3-digit numbers is 445544 = 913 x 488
# the largest palindrome made from the product of two 3-digit numbers is 302203 = 913 x 331
# the largest palindrome made from the product of two 3-digit numbers is 286682 = 913 x 314
# the largest palindrome made from the product of two 3-digit numbers is 143341 = 913 x 157
# the largest palindrome made from the product of two 3-digit numbers is 551155 = 911 x 605
# the largest palindrome made from the product of two 3-digit numbers is 99299 = 911 x 109
# the largest palindrome made from the product of two 3-digit numbers is 819918 = 909 x 902
# the largest palindrome made from the product of two 3-digit numbers is 729927 = 909 x 803
# the largest palindrome made from the product of two 3-digit numbers is 639936 = 909 x 704
# the largest palindrome made from the product of two 3-digit numbers is 549945 = 909 x 605
# the largest palindrome made from the product of two 3-digit numbers is 459954 = 909 x 506
# the largest palindrome made from the product of two 3-digit numbers is 369963 = 909 x 407
# the largest palindrome made from the product of two 3-digit numbers is 279972 = 909 x 308
# the largest palindrome made from the product of two 3-digit numbers is 189981 = 909 x 209
# the largest palindrome made from the product of two 3-digit numbers is 657756 = 906 x 726
# the largest palindrome made from the product of two 3-digit numbers is 507705 = 905 x 561
# the largest palindrome made from the product of two 3-digit numbers is 407704 = 904 x 451
# the largest palindrome made from the product of two 3-digit numbers is 168861 = 903 x 187
# the largest palindrome made from the product of two 3-digit numbers is 824428 = 902 x 914
# the largest palindrome made from the product of two 3-digit numbers is 819918 = 902 x 909
# the largest palindrome made from the product of two 3-digit numbers is 661166 = 902 x 733
# the largest palindrome made from the product of two 3-digit numbers is 656656 = 902 x 728
# the largest palindrome made from the product of two 3-digit numbers is 493394 = 902 x 547
# the largest palindrome made from the product of two 3-digit numbers is 488884 = 902 x 542
# the largest palindrome made from the product of two 3-digit numbers is 412214 = 902 x 457
# the largest palindrome made from the product of two 3-digit numbers is 407704 = 902 x 452
# the largest palindrome made from the product of two 3-digit numbers is 244442 = 902 x 271
# the largest palindrome made from the product of two 3-digit numbers is 239932 = 902 x 266
# the largest palindrome made from the product of two 3-digit numbers is 828828 = 897 x 924
# the largest palindrome made from the product of two 3-digit numbers is 414414 = 897 x 462
# the largest palindrome made from the product of two 3-digit numbers is 561165 = 895 x 627
# the largest palindrome made from the product of two 3-digit numbers is 855558 = 894 x 957
# the largest palindrome made from the product of two 3-digit numbers is 461164 = 892 x 517
# the largest palindrome made from the product of two 3-digit numbers is 840048 = 888 x 946
# the largest palindrome made from the product of two 3-digit numbers is 654456 = 888 x 737
# the largest palindrome made from the product of two 3-digit numbers is 468864 = 888 x 528
# the largest palindrome made from the product of two 3-digit numbers is 420024 = 888 x 473
# the largest palindrome made from the product of two 3-digit numbers is 234432 = 888 x 264
# the largest palindrome made from the product of two 3-digit numbers is 536635 = 887 x 605
# the largest palindrome made from the product of two 3-digit numbers is 428824 = 886 x 484
# the largest palindrome made from the product of two 3-digit numbers is 214412 = 886 x 242
# the largest palindrome made from the product of two 3-digit numbers is 272272 = 884 x 308
# the largest palindrome made from the product of two 3-digit numbers is 602206 = 883 x 682
# the largest palindrome made from the product of two 3-digit numbers is 301103 = 883 x 341
# the largest palindrome made from the product of two 3-digit numbers is 252252 = 882 x 286
# the largest palindrome made from the product of two 3-digit numbers is 106601 = 881 x 121
# the largest palindrome made from the product of two 3-digit numbers is 618816 = 879 x 704
# the largest palindrome made from the product of two 3-digit numbers is 357753 = 879 x 407
# the largest palindrome made from the product of two 3-digit numbers is 280082 = 878 x 319
# the largest palindrome made from the product of two 3-digit numbers is 93839 = 877 x 107
# the largest palindrome made from the product of two 3-digit numbers is 663366 = 874 x 759
# the largest palindrome made from the product of two 3-digit numbers is 442244 = 874 x 506
# the largest palindrome made from the product of two 3-digit numbers is 221122 = 874 x 253
# the largest palindrome made from the product of two 3-digit numbers is 652256 = 872 x 748
# the largest palindrome made from the product of two 3-digit numbers is 737737 = 871 x 847
# the largest palindrome made from the product of two 3-digit numbers is 853358 = 869 x 982
# the largest palindrome made from the product of two 3-digit numbers is 809908 = 869 x 932
# the largest palindrome made from the product of two 3-digit numbers is 793397 = 869 x 913
# the largest palindrome made from the product of two 3-digit numbers is 749947 = 869 x 863
# the largest palindrome made from the product of two 3-digit numbers is 689986 = 869 x 794
# the largest palindrome made from the product of two 3-digit numbers is 534435 = 869 x 615
# the largest palindrome made from the product of two 3-digit numbers is 474474 = 869 x 546
# the largest palindrome made from the product of two 3-digit numbers is 215512 = 869 x 248
# the largest palindrome made from the product of two 3-digit numbers is 155551 = 869 x 179
# the largest palindrome made from the product of two 3-digit numbers is 821128 = 868 x 946
# the largest palindrome made from the product of two 3-digit numbers is 801108 = 867 x 924
# the largest palindrome made from the product of two 3-digit numbers is 89198 = 866 x 103
# the largest palindrome made from the product of two 3-digit numbers is 523325 = 865 x 605
# the largest palindrome made from the product of two 3-digit numbers is 749947 = 863 x 869
# the largest palindrome made from the product of two 3-digit numbers is 198891 = 861 x 231
# the largest palindrome made from the product of two 3-digit numbers is 828828 = 858 x 966
# the largest palindrome made from the product of two 3-digit numbers is 696696 = 858 x 812
# the largest palindrome made from the product of two 3-digit numbers is 666666 = 858 x 777
# the largest palindrome made from the product of two 3-digit numbers is 636636 = 858 x 742
# the largest palindrome made from the product of two 3-digit numbers is 606606 = 858 x 707
# the largest palindrome made from the product of two 3-digit numbers is 474474 = 858 x 553
# the largest palindrome made from the product of two 3-digit numbers is 444444 = 858 x 518
# the largest palindrome made from the product of two 3-digit numbers is 414414 = 858 x 483
# the largest palindrome made from the product of two 3-digit numbers is 282282 = 858 x 329
# the largest palindrome made from the product of two 3-digit numbers is 252252 = 858 x 294
# the largest palindrome made from the product of two 3-digit numbers is 222222 = 858 x 259
# the largest palindrome made from the product of two 3-digit numbers is 675576 = 853 x 792
# the largest palindrome made from the product of two 3-digit numbers is 345543 = 849 x 407
# the largest palindrome made from the product of two 3-digit numbers is 802208 = 848 x 946
# the largest palindrome made from the product of two 3-digit numbers is 447744 = 848 x 528
# the largest palindrome made from the product of two 3-digit numbers is 401104 = 848 x 473
# the largest palindrome made from the product of two 3-digit numbers is 780087 = 847 x 921
# the largest palindrome made from the product of two 3-digit numbers is 737737 = 847 x 871
# the largest palindrome made from the product of two 3-digit numbers is 616616 = 847 x 728
# the largest palindrome made from the product of two 3-digit numbers is 484484 = 847 x 572
# the largest palindrome made from the product of two 3-digit numbers is 363363 = 847 x 429
# the largest palindrome made from the product of two 3-digit numbers is 242242 = 847 x 286
# the largest palindrome made from the product of two 3-digit numbers is 188881 = 847 x 223
# the largest palindrome made from the product of two 3-digit numbers is 121121 = 847 x 143
# the largest palindrome made from the product of two 3-digit numbers is 99099 = 847 x 117
# the largest palindrome made from the product of two 3-digit numbers is 88088 = 847 x 104
# the largest palindrome made from the product of two 3-digit numbers is 297792 = 846 x 352
# the largest palindrome made from the product of two 3-digit numbers is 585585 = 845 x 693
# the largest palindrome made from the product of two 3-digit numbers is 807708 = 844 x 957
# the largest palindrome made from the product of two 3-digit numbers is 259952 = 844 x 308
# the largest palindrome made from the product of two 3-digit numbers is 510015 = 843 x 605
# the largest palindrome made from the product of two 3-digit numbers is 95259 = 843 x 113
# the largest palindrome made from the product of two 3-digit numbers is 508805 = 841 x 605
# the largest palindrome made from the product of two 3-digit numbers is 397793 = 841 x 473
# the largest palindrome made from the product of two 3-digit numbers is 698896 = 836 x 836
# the largest palindrome made from the product of two 3-digit numbers is 611116 = 836 x 731
# the largest palindrome made from the product of two 3-digit numbers is 442244 = 836 x 529
# the largest palindrome made from the product of two 3-digit numbers is 425524 = 836 x 509
# the largest palindrome made from the product of two 3-digit numbers is 408804 = 836 x 489
# the largest palindrome made from the product of two 3-digit numbers is 290092 = 836 x 347
# the largest palindrome made from the product of two 3-digit numbers is 273372 = 836 x 327
# the largest palindrome made from the product of two 3-digit numbers is 256652 = 836 x 307
# the largest palindrome made from the product of two 3-digit numbers is 239932 = 836 x 287
# the largest palindrome made from the product of two 3-digit numbers is 678876 = 834 x 814
# the largest palindrome made from the product of two 3-digit numbers is 595595 = 833 x 715
# the largest palindrome made from the product of two 3-digit numbers is 219912 = 833 x 264
# the largest palindrome made from the product of two 3-digit numbers is 804408 = 831 x 968
# the largest palindrome made from the product of two 3-digit numbers is 603306 = 831 x 726
# the largest palindrome made from the product of two 3-digit numbers is 402204 = 831 x 484
# the largest palindrome made from the product of two 3-digit numbers is 201102 = 831 x 242
# the largest palindrome made from the product of two 3-digit numbers is 98889 = 831 x 119
# the largest palindrome made from the product of two 3-digit numbers is 579975 = 825 x 703
# the largest palindrome made from the product of two 3-digit numbers is 576675 = 825 x 699
# the largest palindrome made from the product of two 3-digit numbers is 573375 = 825 x 695
# the largest palindrome made from the product of two 3-digit numbers is 570075 = 825 x 691
# the largest palindrome made from the product of two 3-digit numbers is 528825 = 825 x 641
# the largest palindrome made from the product of two 3-digit numbers is 525525 = 825 x 637
# the largest palindrome made from the product of two 3-digit numbers is 522225 = 825 x 633
# the largest palindrome made from the product of two 3-digit numbers is 462264 = 824 x 561
# the largest palindrome made from the product of two 3-digit numbers is 84048 = 824 x 102
# the largest palindrome made from the product of two 3-digit numbers is 371173 = 823 x 451
# the largest palindrome made from the product of two 3-digit numbers is 660066 = 822 x 803
# the largest palindrome made from the product of two 3-digit numbers is 89598 = 822 x 109
# the largest palindrome made from the product of two 3-digit numbers is 747747 = 819 x 913
# the largest palindrome made from the product of two 3-digit numbers is 666666 = 819 x 814
# the largest palindrome made from the product of two 3-digit numbers is 585585 = 819 x 715
# the largest palindrome made from the product of two 3-digit numbers is 414414 = 819 x 506
# the largest palindrome made from the product of two 3-digit numbers is 333333 = 819 x 407
# the largest palindrome made from the product of two 3-digit numbers is 252252 = 819 x 308
# the largest palindrome made from the product of two 3-digit numbers is 171171 = 819 x 209
# the largest palindrome made from the product of two 3-digit numbers is 99099 = 819 x 121
# the largest palindrome made from the product of two 3-digit numbers is 90909 = 819 x 111
# the largest palindrome made from the product of two 3-digit numbers is 83538 = 819 x 102
# the largest palindrome made from the product of two 3-digit numbers is 611116 = 817 x 748
# the largest palindrome made from the product of two 3-digit numbers is 84048 = 816 x 103
# the largest palindrome made from the product of two 3-digit numbers is 678876 = 814 x 834
# the largest palindrome made from the product of two 3-digit numbers is 666666 = 814 x 819
# the largest palindrome made from the product of two 3-digit numbers is 654456 = 814 x 804
# the largest palindrome made from the product of two 3-digit numbers is 642246 = 814 x 789
# the largest palindrome made from the product of two 3-digit numbers is 630036 = 814 x 774
# the largest palindrome made from the product of two 3-digit numbers is 468864 = 814 x 576
# the largest palindrome made from the product of two 3-digit numbers is 456654 = 814 x 561
# the largest palindrome made from the product of two 3-digit numbers is 444444 = 814 x 546
# the largest palindrome made from the product of two 3-digit numbers is 432234 = 814 x 531
# the largest palindrome made from the product of two 3-digit numbers is 420024 = 814 x 516
# the largest palindrome made from the product of two 3-digit numbers is 258852 = 814 x 318
# the largest palindrome made from the product of two 3-digit numbers is 246642 = 814 x 303
# the largest palindrome made from the product of two 3-digit numbers is 234432 = 814 x 288
# the largest palindrome made from the product of two 3-digit numbers is 222222 = 814 x 273
# the largest palindrome made from the product of two 3-digit numbers is 210012 = 814 x 258
# the largest palindrome made from the product of two 3-digit numbers is 366663 = 813 x 451
# the largest palindrome made from the product of two 3-digit numbers is 99999 = 813 x 123
# the largest palindrome made from the product of two 3-digit numbers is 696696 = 812 x 858
# the largest palindrome made from the product of two 3-digit numbers is 464464 = 812 x 572
# the largest palindrome made from the product of two 3-digit numbers is 232232 = 812 x 286
# the largest palindrome made from the product of two 3-digit numbers is 84448 = 812 x 104
# the largest palindrome made from the product of two 3-digit numbers is 639936 = 808 x 792
# the largest palindrome made from the product of two 3-digit numbers is 426624 = 808 x 528
# the largest palindrome made from the product of two 3-digit numbers is 257752 = 808 x 319
# the largest palindrome made from the product of two 3-digit numbers is 213312 = 808 x 264
# the largest palindrome made from the product of two 3-digit numbers is 434434 = 806 x 539
# the largest palindrome made from the product of two 3-digit numbers is 575575 = 805 x 715
# the largest palindrome made from the product of two 3-digit numbers is 654456 = 804 x 814
# the largest palindrome made from the product of two 3-digit numbers is 770077 = 803 x 959
# the largest palindrome made from the product of two 3-digit numbers is 729927 = 803 x 909
# the largest palindrome made from the product of two 3-digit numbers is 660066 = 803 x 822
# the largest palindrome made from the product of two 3-digit numbers is 619916 = 803 x 772
# the largest palindrome made from the product of two 3-digit numbers is 550055 = 803 x 685
# the largest palindrome made from the product of two 3-digit numbers is 509905 = 803 x 635
# the largest palindrome made from the product of two 3-digit numbers is 440044 = 803 x 548
# the largest palindrome made from the product of two 3-digit numbers is 330033 = 803 x 411
# the largest palindrome made from the product of two 3-digit numbers is 292292 = 803 x 364
# the largest palindrome made from the product of two 3-digit numbers is 220022 = 803 x 274
# the largest palindrome made from the product of two 3-digit numbers is 182281 = 803 x 227
# the largest palindrome made from the product of two 3-digit numbers is 110011 = 803 x 137
# the largest palindrome made from the product of two 3-digit numbers is 378873 = 801 x 473
# the largest palindrome made from the product of two 3-digit numbers is 689986 = 794 x 869
# the largest palindrome made from the product of two 3-digit numbers is 675576 = 792 x 853
# the largest palindrome made from the product of two 3-digit numbers is 639936 = 792 x 808
# the largest palindrome made from the product of two 3-digit numbers is 612216 = 792 x 773
# the largest palindrome made from the product of two 3-digit numbers is 468864 = 792 x 592
# the largest palindrome made from the product of two 3-digit numbers is 441144 = 792 x 557
# the largest palindrome made from the product of two 3-digit numbers is 405504 = 792 x 512
# the largest palindrome made from the product of two 3-digit numbers is 297792 = 792 x 376
# the largest palindrome made from the product of two 3-digit numbers is 270072 = 792 x 341
# the largest palindrome made from the product of two 3-digit numbers is 234432 = 792 x 296
# the largest palindrome made from the product of two 3-digit numbers is 565565 = 791 x 715
# the largest palindrome made from the product of two 3-digit numbers is 642246 = 789 x 814
# the largest palindrome made from the product of two 3-digit numbers is 321123 = 789 x 407
# the largest palindrome made from the product of two 3-digit numbers is 276672 = 786 x 352
# the largest palindrome made from the product of two 3-digit numbers is 266662 = 782 x 341
# the largest palindrome made from the product of two 3-digit numbers is 84348 = 781 x 108
# the largest palindrome made from the product of two 3-digit numbers is 239932 = 779 x 308
# the largest palindrome made from the product of two 3-digit numbers is 666666 = 777 x 858
# the largest palindrome made from the product of two 3-digit numbers is 555555 = 777 x 715
# the largest palindrome made from the product of two 3-digit numbers is 444444 = 777 x 572
# the largest palindrome made from the product of two 3-digit numbers is 333333 = 777 x 429
# the largest palindrome made from the product of two 3-digit numbers is 222222 = 777 x 286
# the largest palindrome made from the product of two 3-digit numbers is 111111 = 777 x 143
# the largest palindrome made from the product of two 3-digit numbers is 90909 = 777 x 117
# the largest palindrome made from the product of two 3-digit numbers is 80808 = 777 x 104
# the largest palindrome made from the product of two 3-digit numbers is 571175 = 775 x 737
# the largest palindrome made from the product of two 3-digit numbers is 520025 = 775 x 671
# the largest palindrome made from the product of two 3-digit numbers is 630036 = 774 x 814
# the largest palindrome made from the product of two 3-digit numbers is 612216 = 773 x 792
# the largest palindrome made from the product of two 3-digit numbers is 619916 = 772 x 803
# the largest palindrome made from the product of two 3-digit numbers is 84148 = 772 x 109
# the largest palindrome made from the product of two 3-digit numbers is 489984 = 768 x 638
# the largest palindrome made from the product of two 3-digit numbers is 447744 = 768 x 583
# the largest palindrome made from the product of two 3-digit numbers is 405504 = 768 x 528
# the largest palindrome made from the product of two 3-digit numbers is 82728 = 766 x 108
# the largest palindrome made from the product of two 3-digit numbers is 513315 = 765 x 671
# the largest palindrome made from the product of two 3-digit numbers is 545545 = 763 x 715
# the largest palindrome made from the product of two 3-digit numbers is 477774 = 762 x 627
# the largest palindrome made from the product of two 3-digit numbers is 86868 = 762 x 114
# the largest palindrome made from the product of two 3-digit numbers is 359953 = 761 x 473
# the largest palindrome made from the product of two 3-digit numbers is 89798 = 761 x 118
# the largest palindrome made from the product of two 3-digit numbers is 723327 = 759 x 953
# the largest palindrome made from the product of two 3-digit numbers is 663366 = 759 x 874
# the largest palindrome made from the product of two 3-digit numbers is 519915 = 759 x 685
# the largest palindrome made from the product of two 3-digit numbers is 459954 = 759 x 606
# the largest palindrome made from the product of two 3-digit numbers is 414414 = 759 x 546
# the largest palindrome made from the product of two 3-digit numbers is 399993 = 759 x 527
# the largest palindrome made from the product of two 3-digit numbers is 354453 = 759 x 467
# the largest palindrome made from the product of two 3-digit numbers is 294492 = 759 x 388
# the largest palindrome made from the product of two 3-digit numbers is 105501 = 759 x 139
# the largest palindrome made from the product of two 3-digit numbers is 506605 = 755 x 671
# the largest palindrome made from the product of two 3-digit numbers is 696696 = 754 x 924
# the largest palindrome made from the product of two 3-digit numbers is 464464 = 754 x 616
# the largest palindrome made from the product of two 3-digit numbers is 232232 = 754 x 308
# the largest palindrome made from the product of two 3-digit numbers is 84448 = 754 x 112
# the largest palindrome made from the product of two 3-digit numbers is 297792 = 752 x 396
# the largest palindrome made from the product of two 3-digit numbers is 535535 = 749 x 715
# the largest palindrome made from the product of two 3-digit numbers is 693396 = 748 x 927
# the largest palindrome made from the product of two 3-digit numbers is 652256 = 748 x 872
# the largest palindrome made from the product of two 3-digit numbers is 611116 = 748 x 817
# the largest palindrome made from the product of two 3-digit numbers is 462264 = 748 x 618
# the largest palindrome made from the product of two 3-digit numbers is 421124 = 748 x 563
# the largest palindrome made from the product of two 3-digit numbers is 409904 = 748 x 548
# the largest palindrome made from the product of two 3-digit numbers is 272272 = 748 x 364
# the largest palindrome made from the product of two 3-digit numbers is 231132 = 748 x 309
# the largest palindrome made from the product of two 3-digit numbers is 219912 = 748 x 294
# the largest palindrome made from the product of two 3-digit numbers is 86768 = 748 x 116
# the largest palindrome made from the product of two 3-digit numbers is 85158 = 747 x 114
# the largest palindrome made from the product of two 3-digit numbers is 270072 = 744 x 363
# the largest palindrome made from the product of two 3-digit numbers is 636636 = 742 x 858
# the largest palindrome made from the product of two 3-digit numbers is 424424 = 742 x 572
# the largest palindrome made from the product of two 3-digit numbers is 212212 = 742 x 286
# the largest palindrome made from the product of two 3-digit numbers is 171171 = 741 x 231
# the largest palindrome made from the product of two 3-digit numbers is 154451 = 739 x 209
# the largest palindrome made from the product of two 3-digit numbers is 89298 = 738 x 121
# the largest palindrome made from the product of two 3-digit numbers is 81918 = 738 x 111
# the largest palindrome made from the product of two 3-digit numbers is 654456 = 737 x 888
# the largest palindrome made from the product of two 3-digit numbers is 571175 = 737 x 775
# the largest palindrome made from the product of two 3-digit numbers is 512215 = 737 x 695
# the largest palindrome made from the product of two 3-digit numbers is 367763 = 737 x 499
# the largest palindrome made from the product of two 3-digit numbers is 308803 = 737 x 419
# the largest palindrome made from the product of two 3-digit numbers is 284482 = 737 x 386
# the largest palindrome made from the product of two 3-digit numbers is 225522 = 737 x 306
# the largest palindrome made from the product of two 3-digit numbers is 142241 = 737 x 193
# the largest palindrome made from the product of two 3-digit numbers is 525525 = 735 x 715
# the largest palindrome made from the product of two 3-digit numbers is 661166 = 733 x 902
# the largest palindrome made from the product of two 3-digit numbers is 79897 = 733 x 109
# the largest palindrome made from the product of two 3-digit numbers is 611116 = 731 x 836
# the largest palindrome made from the product of two 3-digit numbers is 168861 = 731 x 231
# the largest palindrome made from the product of two 3-digit numbers is 696696 = 728 x 957
# the largest palindrome made from the product of two 3-digit numbers is 656656 = 728 x 902
# the largest palindrome made from the product of two 3-digit numbers is 616616 = 728 x 847
# the largest palindrome made from the product of two 3-digit numbers is 464464 = 728 x 638
# the largest palindrome made from the product of two 3-digit numbers is 424424 = 728 x 583
# the largest palindrome made from the product of two 3-digit numbers is 272272 = 728 x 374
# the largest palindrome made from the product of two 3-digit numbers is 232232 = 728 x 319
# the largest palindrome made from the product of two 3-digit numbers is 88088 = 728 x 121
# the largest palindrome made from the product of two 3-digit numbers is 84448 = 728 x 116
# the largest palindrome made from the product of two 3-digit numbers is 80808 = 728 x 111
# the largest palindrome made from the product of two 3-digit numbers is 99599 = 727 x 137
# the largest palindrome made from the product of two 3-digit numbers is 92329 = 727 x 127
# the largest palindrome made from the product of two 3-digit numbers is 672276 = 726 x 926
# the largest palindrome made from the product of two 3-digit numbers is 657756 = 726 x 906
# the largest palindrome made from the product of two 3-digit numbers is 603306 = 726 x 831
# the largest palindrome made from the product of two 3-digit numbers is 471174 = 726 x 649
# the largest palindrome made from the product of two 3-digit numbers is 456654 = 726 x 629
# the largest palindrome made from the product of two 3-digit numbers is 402204 = 726 x 554
# the largest palindrome made from the product of two 3-digit numbers is 270072 = 726 x 372
# the largest palindrome made from the product of two 3-digit numbers is 255552 = 726 x 352
# the largest palindrome made from the product of two 3-digit numbers is 201102 = 726 x 277
# the largest palindrome made from the product of two 3-digit numbers is 89298 = 726 x 123
# the largest palindrome made from the product of two 3-digit numbers is 698896 = 722 x 968
# the largest palindrome made from the product of two 3-digit numbers is 515515 = 721 x 715
# the largest palindrome made from the product of two 3-digit numbers is 80908 = 716 x 113
# the largest palindrome made from the product of two 3-digit numbers is 595595 = 715 x 833
# the largest palindrome made from the product of two 3-digit numbers is 585585 = 715 x 819
# the largest palindrome made from the product of two 3-digit numbers is 575575 = 715 x 805
# the largest palindrome made from the product of two 3-digit numbers is 565565 = 715 x 791
# the largest palindrome made from the product of two 3-digit numbers is 555555 = 715 x 777
# the largest palindrome made from the product of two 3-digit numbers is 545545 = 715 x 763
# the largest palindrome made from the product of two 3-digit numbers is 535535 = 715 x 749
# the largest palindrome made from the product of two 3-digit numbers is 525525 = 715 x 735
# the largest palindrome made from the product of two 3-digit numbers is 515515 = 715 x 721
# the largest palindrome made from the product of two 3-digit numbers is 505505 = 715 x 707
# the largest palindrome made from the product of two 3-digit numbers is 219912 = 714 x 308
# the largest palindrome made from the product of two 3-digit numbers is 83538 = 714 x 117
# the largest palindrome made from the product of two 3-digit numbers is 399993 = 713 x 561
# the largest palindrome made from the product of two 3-digit numbers is 266662 = 713 x 374
# the largest palindrome made from the product of two 3-digit numbers is 133331 = 713 x 187
# the largest palindrome made from the product of two 3-digit numbers is 650056 = 712 x 913
# the largest palindrome made from the product of two 3-digit numbers is 485584 = 712 x 682
# the largest palindrome made from the product of two 3-digit numbers is 88288 = 712 x 124
# the largest palindrome made from the product of two 3-digit numbers is 91719 = 711 x 129
# the largest palindrome made from the product of two 3-digit numbers is 82128 = 708 x 116
# the largest palindrome made from the product of two 3-digit numbers is 606606 = 707 x 858
# the largest palindrome made from the product of two 3-digit numbers is 505505 = 707 x 715
# the largest palindrome made from the product of two 3-digit numbers is 404404 = 707 x 572
# the largest palindrome made from the product of two 3-digit numbers is 303303 = 707 x 429
# the largest palindrome made from the product of two 3-digit numbers is 279972 = 707 x 396
# the largest palindrome made from the product of two 3-digit numbers is 202202 = 707 x 286
# the largest palindrome made from the product of two 3-digit numbers is 178871 = 707 x 253
# the largest palindrome made from the product of two 3-digit numbers is 101101 = 707 x 143
# the largest palindrome made from the product of two 3-digit numbers is 639936 = 704 x 909
# the largest palindrome made from the product of two 3-digit numbers is 618816 = 704 x 879
# the largest palindrome made from the product of two 3-digit numbers is 489984 = 704 x 696
# the largest palindrome made from the product of two 3-digit numbers is 468864 = 704 x 666
# the largest palindrome made from the product of two 3-digit numbers is 447744 = 704 x 636
# the largest palindrome made from the product of two 3-digit numbers is 426624 = 704 x 606
# the largest palindrome made from the product of two 3-digit numbers is 405504 = 704 x 576
# the largest palindrome made from the product of two 3-digit numbers is 297792 = 704 x 423
# the largest palindrome made from the product of two 3-digit numbers is 276672 = 704 x 393
# the largest palindrome made from the product of two 3-digit numbers is 255552 = 704 x 363
# the largest palindrome made from the product of two 3-digit numbers is 234432 = 704 x 333
# the largest palindrome made from the product of two 3-digit numbers is 213312 = 704 x 303
# the largest palindrome made from the product of two 3-digit numbers is 579975 = 703 x 825
# the largest palindrome made from the product of two 3-digit numbers is 83538 = 702 x 119
# the largest palindrome made from the product of two 3-digit numbers is 576675 = 699 x 825
# the largest palindrome made from the product of two 3-digit numbers is 78987 = 699 x 113
# the largest palindrome made from the product of two 3-digit numbers is 489984 = 696 x 704
# the largest palindrome made from the product of two 3-digit numbers is 82128 = 696 x 118
# the largest palindrome made from the product of two 3-digit numbers is 573375 = 695 x 825
# the largest palindrome made from the product of two 3-digit numbers is 512215 = 695 x 737
# the largest palindrome made from the product of two 3-digit numbers is 290092 = 694 x 418
# the largest palindrome made from the product of two 3-digit numbers is 666666 = 693 x 962
# the largest palindrome made from the product of two 3-digit numbers is 585585 = 693 x 845
# the largest palindrome made from the product of two 3-digit numbers is 414414 = 693 x 598
# the largest palindrome made from the product of two 3-digit numbers is 333333 = 693 x 481
# the largest palindrome made from the product of two 3-digit numbers is 279972 = 693 x 404
# the largest palindrome made from the product of two 3-digit numbers is 252252 = 693 x 364
# the largest palindrome made from the product of two 3-digit numbers is 198891 = 693 x 287
# the largest palindrome made from the product of two 3-digit numbers is 171171 = 693 x 247
# the largest palindrome made from the product of two 3-digit numbers is 108801 = 693 x 157
# the largest palindrome made from the product of two 3-digit numbers is 99099 = 693 x 143
# the largest palindrome made from the product of two 3-digit numbers is 570075 = 691 x 825
# the largest palindrome made from the product of two 3-digit numbers is 73937 = 691 x 107
# the largest palindrome made from the product of two 3-digit numbers is 636636 = 689 x 924
# the largest palindrome made from the product of two 3-digit numbers is 424424 = 689 x 616
# the largest palindrome made from the product of two 3-digit numbers is 212212 = 689 x 308
# the largest palindrome made from the product of two 3-digit numbers is 401104 = 688 x 583
# the largest palindrome made from the product of two 3-digit numbers is 550055 = 685 x 803
# the largest palindrome made from the product of two 3-digit numbers is 519915 = 685 x 759
# the largest palindrome made from the product of two 3-digit numbers is 86868 = 684 x 127
# the largest palindrome made from the product of two 3-digit numbers is 127721 = 683 x 187
# the largest palindrome made from the product of two 3-digit numbers is 74447 = 683 x 109
# the largest palindrome made from the product of two 3-digit numbers is 653356 = 682 x 958
# the largest palindrome made from the product of two 3-digit numbers is 649946 = 682 x 953
# the largest palindrome made from the product of two 3-digit numbers is 602206 = 682 x 883
# the largest palindrome made from the product of two 3-digit numbers is 485584 = 682 x 712
# the largest palindrome made from the product of two 3-digit numbers is 434434 = 682 x 637
# the largest palindrome made from the product of two 3-digit numbers is 270072 = 682 x 396
# the largest palindrome made from the product of two 3-digit numbers is 266662 = 682 x 391
# the largest palindrome made from the product of two 3-digit numbers is 215512 = 682 x 316
# the largest palindrome made from the product of two 3-digit numbers is 87978 = 682 x 129
# the largest palindrome made from the product of two 3-digit numbers is 648846 = 678 x 957
# the largest palindrome made from the product of two 3-digit numbers is 452254 = 674 x 671
# the largest palindrome made from the product of two 3-digit numbers is 82228 = 674 x 122
# the largest palindrome made from the product of two 3-digit numbers is 520025 = 671 x 775
# the largest palindrome made from the product of two 3-digit numbers is 513315 = 671 x 765
# the largest palindrome made from the product of two 3-digit numbers is 506605 = 671 x 755
# the largest palindrome made from the product of two 3-digit numbers is 452254 = 671 x 674
# the largest palindrome made from the product of two 3-digit numbers is 445544 = 671 x 664
# the largest palindrome made from the product of two 3-digit numbers is 438834 = 671 x 654
# the largest palindrome made from the product of two 3-digit numbers is 391193 = 671 x 583
# the largest palindrome made from the product of two 3-digit numbers is 384483 = 671 x 573
# the largest palindrome made from the product of two 3-digit numbers is 377773 = 671 x 563
# the largest palindrome made from the product of two 3-digit numbers is 81618 = 669 x 122
# the largest palindrome made from the product of two 3-digit numbers is 630036 = 666 x 946
# the largest palindrome made from the product of two 3-digit numbers is 468864 = 666 x 704
# the largest palindrome made from the product of two 3-digit numbers is 432234 = 666 x 649
# the largest palindrome made from the product of two 3-digit numbers is 234432 = 666 x 352
# the largest palindrome made from the product of two 3-digit numbers is 81918 = 666 x 123
# the largest palindrome made from the product of two 3-digit numbers is 650056 = 664 x 979
# the largest palindrome made from the product of two 3-digit numbers is 445544 = 664 x 671
# the largest palindrome made from the product of two 3-digit numbers is 83538 = 663 x 126
# the largest palindrome made from the product of two 3-digit numbers is 604406 = 662 x 913
# the largest palindrome made from the product of two 3-digit numbers is 68186 = 662 x 103
# the largest palindrome made from the product of two 3-digit numbers is 98489 = 661 x 149
# the largest palindrome made from the product of two 3-digit numbers is 137731 = 659 x 209
# the largest palindrome made from the product of two 3-digit numbers is 282282 = 658 x 429
# the largest palindrome made from the product of two 3-digit numbers is 209902 = 658 x 319
# the largest palindrome made from the product of two 3-digit numbers is 90009 = 657 x 137
# the largest palindrome made from the product of two 3-digit numbers is 79497 = 657 x 121
# the largest palindrome made from the product of two 3-digit numbers is 72927 = 657 x 111
# the largest palindrome made from the product of two 3-digit numbers is 438834 = 654 x 671
# the largest palindrome made from the product of two 3-digit numbers is 273372 = 654 x 418
# the largest palindrome made from the product of two 3-digit numbers is 89598 = 654 x 137
# the largest palindrome made from the product of two 3-digit numbers is 416614 = 653 x 638
# the largest palindrome made from the product of two 3-digit numbers is 631136 = 652 x 968
# the largest palindrome made from the product of two 3-digit numbers is 408804 = 652 x 627
# the largest palindrome made from the product of two 3-digit numbers is 76167 = 651 x 117
# the largest palindrome made from the product of two 3-digit numbers is 471174 = 649 x 726
# the largest palindrome made from the product of two 3-digit numbers is 432234 = 649 x 666
# the largest palindrome made from the product of two 3-digit numbers is 374473 = 649 x 577
# the largest palindrome made from the product of two 3-digit numbers is 335533 = 649 x 517
# the largest palindrome made from the product of two 3-digit numbers is 277772 = 649 x 428
# the largest palindrome made from the product of two 3-digit numbers is 238832 = 649 x 368
# the largest palindrome made from the product of two 3-digit numbers is 73337 = 649 x 113
# the largest palindrome made from the product of two 3-digit numbers is 78287 = 647 x 121
# ...
# the largest palindrome made from the product of two 3-digit numbers is 30303 = 117 x 259
# the largest palindrome made from the product of two 3-digit numbers is 28782 = 117 x 246
# the largest palindrome made from the product of two 3-digit numbers is 86768 = 116 x 748
# the largest palindrome made from the product of two 3-digit numbers is 84448 = 116 x 728
# the largest palindrome made from the product of two 3-digit numbers is 82128 = 116 x 708
# the largest palindrome made from the product of two 3-digit numbers is 67976 = 116 x 586
# the largest palindrome made from the product of two 3-digit numbers is 65656 = 116 x 566
# the largest palindrome made from the product of two 3-digit numbers is 63336 = 116 x 546
# the largest palindrome made from the product of two 3-digit numbers is 61016 = 116 x 526
# the largest palindrome made from the product of two 3-digit numbers is 46864 = 116 x 404
# the largest palindrome made from the product of two 3-digit numbers is 44544 = 116 x 384
# the largest palindrome made from the product of two 3-digit numbers is 42224 = 116 x 364
# the largest palindrome made from the product of two 3-digit numbers is 25752 = 116 x 222
# the largest palindrome made from the product of two 3-digit numbers is 23432 = 116 x 202
# the largest palindrome made from the product of two 3-digit numbers is 21112 = 116 x 182
# the largest palindrome made from the product of two 3-digit numbers is 56465 = 115 x 491
# the largest palindrome made from the product of two 3-digit numbers is 53935 = 115 x 469
# the largest palindrome made from the product of two 3-digit numbers is 52325 = 115 x 455
# the largest palindrome made from the product of two 3-digit numbers is 86868 = 114 x 762
# the largest palindrome made from the product of two 3-digit numbers is 85158 = 114 x 747
# the largest palindrome made from the product of two 3-digit numbers is 69996 = 114 x 614
# the largest palindrome made from the product of two 3-digit numbers is 68286 = 114 x 599
# the largest palindrome made from the product of two 3-digit numbers is 60306 = 114 x 529
# the largest palindrome made from the product of two 3-digit numbers is 43434 = 114 x 381
# the largest palindrome made from the product of two 3-digit numbers is 26562 = 114 x 233
# the largest palindrome made from the product of two 3-digit numbers is 95259 = 113 x 843
# the largest palindrome made from the product of two 3-digit numbers is 80908 = 113 x 716
# the largest palindrome made from the product of two 3-digit numbers is 78987 = 113 x 699
# the largest palindrome made from the product of two 3-digit numbers is 73337 = 113 x 649
# the largest palindrome made from the product of two 3-digit numbers is 51415 = 113 x 455
# the largest palindrome made from the product of two 3-digit numbers is 49494 = 113 x 438
# the largest palindrome made from the product of two 3-digit numbers is 27572 = 113 x 244
# the largest palindrome made from the product of two 3-digit numbers is 84448 = 112 x 754
# the largest palindrome made from the product of two 3-digit numbers is 65856 = 112 x 588
# the largest palindrome made from the product of two 3-digit numbers is 48384 = 112 x 432
# the largest palindrome made from the product of two 3-digit numbers is 42224 = 112 x 377
# the largest palindrome made from the product of two 3-digit numbers is 29792 = 112 x 266
# the largest palindrome made from the product of two 3-digit numbers is 23632 = 112 x 211
# the largest palindrome made from the product of two 3-digit numbers is 90909 = 111 x 819
# the largest palindrome made from the product of two 3-digit numbers is 81918 = 111 x 738
# the largest palindrome made from the product of two 3-digit numbers is 80808 = 111 x 728
# the largest palindrome made from the product of two 3-digit numbers is 72927 = 111 x 657
# the largest palindrome made from the product of two 3-digit numbers is 71817 = 111 x 647
# the largest palindrome made from the product of two 3-digit numbers is 70707 = 111 x 637
# the largest palindrome made from the product of two 3-digit numbers is 63936 = 111 x 576
# the largest palindrome made from the product of two 3-digit numbers is 62826 = 111 x 566
# the largest palindrome made from the product of two 3-digit numbers is 61716 = 111 x 556
# the largest palindrome made from the product of two 3-digit numbers is 60606 = 111 x 546
# the largest palindrome made from the product of two 3-digit numbers is 54945 = 111 x 495
# the largest palindrome made from the product of two 3-digit numbers is 53835 = 111 x 485
# the largest palindrome made from the product of two 3-digit numbers is 52725 = 111 x 475
# the largest palindrome made from the product of two 3-digit numbers is 51615 = 111 x 465
# the largest palindrome made from the product of two 3-digit numbers is 50505 = 111 x 455
# the largest palindrome made from the product of two 3-digit numbers is 45954 = 111 x 414
# the largest palindrome made from the product of two 3-digit numbers is 44844 = 111 x 404
# the largest palindrome made from the product of two 3-digit numbers is 43734 = 111 x 394
# the largest palindrome made from the product of two 3-digit numbers is 42624 = 111 x 384
# the largest palindrome made from the product of two 3-digit numbers is 41514 = 111 x 374
# the largest palindrome made from the product of two 3-digit numbers is 40404 = 111 x 364
# the largest palindrome made from the product of two 3-digit numbers is 36963 = 111 x 333
# the largest palindrome made from the product of two 3-digit numbers is 35853 = 111 x 323
# the largest palindrome made from the product of two 3-digit numbers is 34743 = 111 x 313
# the largest palindrome made from the product of two 3-digit numbers is 33633 = 111 x 303
# the largest palindrome made from the product of two 3-digit numbers is 32523 = 111 x 293
# the largest palindrome made from the product of two 3-digit numbers is 31413 = 111 x 283
# the largest palindrome made from the product of two 3-digit numbers is 30303 = 111 x 273
# the largest palindrome made from the product of two 3-digit numbers is 27972 = 111 x 252
# the largest palindrome made from the product of two 3-digit numbers is 26862 = 111 x 242
# the largest palindrome made from the product of two 3-digit numbers is 25752 = 111 x 232
# the largest palindrome made from the product of two 3-digit numbers is 24642 = 111 x 222
# the largest palindrome made from the product of two 3-digit numbers is 23532 = 111 x 212
# the largest palindrome made from the product of two 3-digit numbers is 22422 = 111 x 202
# the largest palindrome made from the product of two 3-digit numbers is 21312 = 111 x 192
# the largest palindrome made from the product of two 3-digit numbers is 20202 = 111 x 182
# the largest palindrome made from the product of two 3-digit numbers is 18981 = 111 x 171
# the largest palindrome made from the product of two 3-digit numbers is 17871 = 111 x 161
# the largest palindrome made from the product of two 3-digit numbers is 16761 = 111 x 151
# the largest palindrome made from the product of two 3-digit numbers is 15651 = 111 x 141
# the largest palindrome made from the product of two 3-digit numbers is 14541 = 111 x 131
# the largest palindrome made from the product of two 3-digit numbers is 13431 = 111 x 121
# the largest palindrome made from the product of two 3-digit numbers is 12321 = 111 x 111
# the largest palindrome made from the product of two 3-digit numbers is 11211 = 111 x 101
# the largest palindrome made from the product of two 3-digit numbers is 99299 = 109 x 911
# the largest palindrome made from the product of two 3-digit numbers is 89598 = 109 x 822
# the largest palindrome made from the product of two 3-digit numbers is 84148 = 109 x 772
# the largest palindrome made from the product of two 3-digit numbers is 79897 = 109 x 733
# the largest palindrome made from the product of two 3-digit numbers is 74447 = 109 x 683
# the largest palindrome made from the product of two 3-digit numbers is 64746 = 109 x 594
# the largest palindrome made from the product of two 3-digit numbers is 15151 = 109 x 139
# the largest palindrome made from the product of two 3-digit numbers is 84348 = 108 x 781
# the largest palindrome made from the product of two 3-digit numbers is 82728 = 108 x 766
# the largest palindrome made from the product of two 3-digit numbers is 67176 = 108 x 622
# the largest palindrome made from the product of two 3-digit numbers is 65556 = 108 x 607
# the largest palindrome made from the product of two 3-digit numbers is 63936 = 108 x 592
# the largest palindrome made from the product of two 3-digit numbers is 48384 = 108 x 448
# the largest palindrome made from the product of two 3-digit numbers is 46764 = 108 x 433
# the largest palindrome made from the product of two 3-digit numbers is 29592 = 108 x 274
# the largest palindrome made from the product of two 3-digit numbers is 27972 = 108 x 259
# the largest palindrome made from the product of two 3-digit numbers is 93839 = 107 x 877
# the largest palindrome made from the product of two 3-digit numbers is 73937 = 107 x 691
# the largest palindrome made from the product of two 3-digit numbers is 65056 = 107 x 608
# the largest palindrome made from the product of two 3-digit numbers is 45154 = 107 x 422
# the largest palindrome made from the product of two 3-digit numbers is 25252 = 107 x 236
# the largest palindrome made from the product of two 3-digit numbers is 44944 = 106 x 424
# the largest palindrome made from the product of two 3-digit numbers is 42824 = 106 x 404
# the largest palindrome made from the product of two 3-digit numbers is 40704 = 106 x 384
# the largest palindrome made from the product of two 3-digit numbers is 29892 = 106 x 282
# the largest palindrome made from the product of two 3-digit numbers is 27772 = 106 x 262
# the largest palindrome made from the product of two 3-digit numbers is 25652 = 106 x 242
# the largest palindrome made from the product of two 3-digit numbers is 23532 = 106 x 222
# the largest palindrome made from the product of two 3-digit numbers is 21412 = 106 x 202
# the largest palindrome made from the product of two 3-digit numbers is 58485 = 105 x 557
# the largest palindrome made from the product of two 3-digit numbers is 55755 = 105 x 531
# the largest palindrome made from the product of two 3-digit numbers is 53235 = 105 x 507
# the largest palindrome made from the product of two 3-digit numbers is 50505 = 105 x 481
# the largest palindrome made from the product of two 3-digit numbers is 88088 = 104 x 847
# the largest palindrome made from the product of two 3-digit numbers is 84448 = 104 x 812
# the largest palindrome made from the product of two 3-digit numbers is 80808 = 104 x 777
# the largest palindrome made from the product of two 3-digit numbers is 63336 = 104 x 609
# the largest palindrome made from the product of two 3-digit numbers is 48984 = 104 x 471
# the largest palindrome made from the product of two 3-digit numbers is 42224 = 104 x 406
# the largest palindrome made from the product of two 3-digit numbers is 27872 = 104 x 268
# the largest palindrome made from the product of two 3-digit numbers is 21112 = 104 x 203
# the largest palindrome made from the product of two 3-digit numbers is 89198 = 103 x 866
# the largest palindrome made from the product of two 3-digit numbers is 84048 = 103 x 816
# the largest palindrome made from the product of two 3-digit numbers is 68186 = 103 x 662
# the largest palindrome made from the product of two 3-digit numbers is 63036 = 103 x 612
# the largest palindrome made from the product of two 3-digit numbers is 47174 = 103 x 458
# the largest palindrome made from the product of two 3-digit numbers is 42024 = 103 x 408
# the largest palindrome made from the product of two 3-digit numbers is 26162 = 103 x 254
# the largest palindrome made from the product of two 3-digit numbers is 21012 = 103 x 204
# the largest palindrome made from the product of two 3-digit numbers is 84048 = 102 x 824
# the largest palindrome made from the product of two 3-digit numbers is 83538 = 102 x 819
# the largest palindrome made from the product of two 3-digit numbers is 63036 = 102 x 618
# the largest palindrome made from the product of two 3-digit numbers is 62526 = 102 x 613
# the largest palindrome made from the product of two 3-digit numbers is 42024 = 102 x 412
# the largest palindrome made from the product of two 3-digit numbers is 41514 = 102 x 407
# the largest palindrome made from the product of two 3-digit numbers is 21012 = 102 x 206
# the largest palindrome made from the product of two 3-digit numbers is 20502 = 102 x 201
# the largest palindrome made from the product of two 3-digit numbers is 49894 = 101 x 494
# the largest palindrome made from the product of two 3-digit numbers is 48884 = 101 x 484
# the largest palindrome made from the product of two 3-digit numbers is 47874 = 101 x 474
# the largest palindrome made from the product of two 3-digit numbers is 46864 = 101 x 464
# the largest palindrome made from the product of two 3-digit numbers is 45854 = 101 x 454
# the largest palindrome made from the product of two 3-digit numbers is 44844 = 101 x 444
# the largest palindrome made from the product of two 3-digit numbers is 43834 = 101 x 434
# the largest palindrome made from the product of two 3-digit numbers is 42824 = 101 x 424
# the largest palindrome made from the product of two 3-digit numbers is 41814 = 101 x 414
# the largest palindrome made from the product of two 3-digit numbers is 40804 = 101 x 404
# the largest palindrome made from the product of two 3-digit numbers is 39693 = 101 x 393
# the largest palindrome made from the product of two 3-digit numbers is 38683 = 101 x 383
# the largest palindrome made from the product of two 3-digit numbers is 37673 = 101 x 373
# the largest palindrome made from the product of two 3-digit numbers is 36663 = 101 x 363
# the largest palindrome made from the product of two 3-digit numbers is 35653 = 101 x 353
# the largest palindrome made from the product of two 3-digit numbers is 34643 = 101 x 343
# the largest palindrome made from the product of two 3-digit numbers is 33633 = 101 x 333
# the largest palindrome made from the product of two 3-digit numbers is 32623 = 101 x 323
# the largest palindrome made from the product of two 3-digit numbers is 31613 = 101 x 313
# the largest palindrome made from the product of two 3-digit numbers is 30603 = 101 x 303
# the largest palindrome made from the product of two 3-digit numbers is 29492 = 101 x 292
# the largest palindrome made from the product of two 3-digit numbers is 28482 = 101 x 282
# the largest palindrome made from the product of two 3-digit numbers is 27472 = 101 x 272
# the largest palindrome made from the product of two 3-digit numbers is 26462 = 101 x 262
# the largest palindrome made from the product of two 3-digit numbers is 25452 = 101 x 252
# the largest palindrome made from the product of two 3-digit numbers is 24442 = 101 x 242
# the largest palindrome made from the product of two 3-digit numbers is 23432 = 101 x 232
# the largest palindrome made from the product of two 3-digit numbers is 22422 = 101 x 222
# the largest palindrome made from the product of two 3-digit numbers is 21412 = 101 x 212
# the largest palindrome made from the product of two 3-digit numbers is 20402 = 101 x 202
# the largest palindrome made from the product of two 3-digit numbers is 19291 = 101 x 191
# the largest palindrome made from the product of two 3-digit numbers is 18281 = 101 x 181
# the largest palindrome made from the product of two 3-digit numbers is 17271 = 101 x 171
# the largest palindrome made from the product of two 3-digit numbers is 16261 = 101 x 161
# the largest palindrome made from the product of two 3-digit numbers is 15251 = 101 x 151
# the largest palindrome made from the product of two 3-digit numbers is 14241 = 101 x 141
# the largest palindrome made from the product of two 3-digit numbers is 13231 = 101 x 131
# the largest palindrome made from the product of two 3-digit numbers is 12221 = 101 x 121
# the largest palindrome made from the product of two 3-digit numbers is 11211 = 101 x 111
# the largest palindrome made from the product of two 3-digit numbers is 10201 = 101 x 101

# %%
maiorPalíndromo3()
# Out:
# the largest palindrome made from the product of two 3-digit numbers is 580085 = 995 x 583
# 580085
